# %% [markdown]
# # “For the things we have to learn before we can do them, we learn by doing them.” ― Aristotle, The Nicomachean Ethics

# %% [markdown]
# # The plan
# 0. The cloud system test
# 1. A short teaser on deep learning capabilities
# 2. A walkthrough for a Caffe example
# 3. You compete in https://inclass.kaggle.com/c/digits-classification-dubna-2015 with me available for assistance

# %% [markdown]
# # The cloud enviroment
# 1. Go to https://everware.rep.school.yandex.net
# 2. Past the repository url https://github.com/yandexdataschool/dubna_dl
# 3. Press the launch button
# 4. Setup may take a few minutes
#
# In case of problems please write to https://gitter.im/yandexdataschool/dubna_dl . The cluster admin Alexander Baranov will help you.

# %% [markdown]
# # Cool things with deep learning
# 1. Handwriting generation http://www.cs.toronto.edu/~graves/handwriting.cgi
# 2. Machine translation http://104.131.78.120/
# 3. Image classification
# 4. Sentiment analysis
# 5. Object search

# %% [markdown]
# # Deep learning idea
# Following http://www.datarobot.com/blog/a-primer-on-deep-learning/
#
#  * A collection of statistical machine learning techniques
#  * Used to learn feature hierarchies
#  * Often based on artificial neural networks

# %%
from IPython.display import Image
Image("https://s3.amazonaws.com/datarobotblog/images/deepLearningIntro/007.png")

# %%
Image("https://s3.amazonaws.com/datarobotblog/images/deepLearningIntro/013.png")

# %% [markdown]
# # Convolutional layer

# %% [markdown]
# http://deeplearning.stanford.edu/wiki/images/6/6c/Convolution_schematic.gif

# %% [markdown]
# https://en.wikipedia.org/wiki/Kernel_(image_processing)

# %% [markdown]
# # MaxPool layer

# %%
Image("http://cs231n.github.io/assets/cnn/maxpool.jpeg")

# %% [markdown]
# # ReLU layer

# %%
Image("https://image.slidesharecdn.com/talk-140611223619-phpapp02/95/talk-32-638.jpg")

# %% [markdown]
# # The competition

# %% [markdown]
# 1. You are given some labeled data - train dataset
# 2. You are given some unlabeled data - test dataset
# 3. You are to recognise the digits on the test dataset
# 4. You can work in team of two
# 4. You are to receive a prize if you win

# %% [markdown]
# # Kaggle
# https://inclass.kaggle.com/c/digits-classification-dubna-2015
# * The test dataset is divided into two parts: public and private
# * On the leaderboard you can view the score you get on the public part
# * The final standings will be calculated on the private part
# * Private code sharing is not allowed - if you share, you must share with everybody via the chat
# * Using external data is not allowed - the model must be trained on the provided examples. If you label a part of the test set by hand, this counts for external data
